# %% [markdown]
# # Evaluation data generation (course)
#
# Use this notebook for **AI-generated questions** and batch logging — the same ideas as **`Day_05_Evaluation.ipynb`** (sample FAQ rows → `question_generator` → `faq_agent_v2` → `log_interaction_to_file(..., source='ai-generated')`).
#
# **Prereq:** run setup cells from `Day_05_Evaluation.ipynb` once, or paste imports + `run_agent_sync` + index loading here.

# %% [markdown]
# ## Next step
#
# Copy the relevant cells from **`course/Day_05_Evaluation.ipynb`** (question generator + `tqdm` loop), then keep this file under version control as your **canonical** data-gen script.
