# %% [markdown]
# # Evaluations (course)
#
# Run **LLM-as-judge** over saved logs and aggregate with **Pandas** — mirror **`Day_05_Evaluation.ipynb`** (`evaluate_log_record_sync`, `eval_set`, `df_evals.mean`).
#
# Export a small **table or bullet list** of pass rates for your **`README.md` → Evaluation** section.

# %% [markdown]
# ## Next step
#
# Copy evaluation cells from **`course/Day_05_Evaluation.ipynb`**, parameterize `LOG_DIR` / agent name filters, and save outputs (e.g. `eval_summary.csv`) if useful.
