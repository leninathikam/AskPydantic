# %% [markdown]
# # Day 7: Polish the repository
#
# You have **pipeline → agent → evals → app**. Turn the repo into a **clear portfolio**: README, evaluation summary, and demo assets.
#
# - **`README.md`** — structure, install, usage, **evaluation metrics**, deployment
# - **`course/eval/`** — optional split from `Day_05_Evaluation.ipynb` (`data-gen.ipynb`, `evaluations.ipynb`)
# - **Demos** — short video and/or screenshots/GIFs in the README
#
# Example layout: [alexeygrigorev/aihero `code/`](https://github.com/alexeygrigorev/aihero/tree/main/code).

# %% [markdown]
# ## 1. `README.md`
#
# Outline (skip sections that do not apply):
#
# 1. Title & one-line description · optional badges
# 2. Overview — problem, screenshots or short demo
# 3. Installation — Python, `uv`/`pip`, env vars
# 4. Usage — CLI, Streamlit
# 5. Features
# 6. Contributing (optional)
# 7. Tests (optional)
# 8. Deployment — secrets, `requirements.txt`
# 9. FAQ (optional)
# 10. Credits — libraries, course materials you used
# 11. License (optional)
#
# For **AI agents**, add an **Evaluation** section: what you measure and headline numbers (e.g. judge pass rates from Day 5).

# %% [markdown]
# ## 2. Evaluations in repo + README
#
# If evaluation code still only lives in **`Day_05_Evaluation.ipynb`**, move stable workflows to:
#
# - **`course/eval/data-gen.ipynb`** — synthetic questions, batch logs
# - **`course/eval/evaluations.ipynb`** — LLM judge, Pandas aggregates
#
# In the README, summarize **metrics** (e.g. `df.mean(numeric_only=True)` per checklist item).

# %% [markdown]
# ## 3. Demo assets
#
# - Short **screen recording** or **screenshots** of CLI / Streamlit
# - Optional GIFs; host under `docs/` / `assets/` or link externally
#
# Visuals help reviewers who will not run the code locally.

# %% [markdown]
# ## 4. Certificate (if you submit for cohort credit)
#
# Typical requirements: **non-course-FAQ dataset**, **pipeline + agent + evals + UI**, **modular Python** (not one monolithic notebook), **README with demo**, and submission via the **form** the course sends. Confirm on the official course page.

# %% [markdown]
# ## Checklist
#
# - [ ] README with overview, install, usage, **Evaluation** numbers, deployment
# - [ ] Eval workflows in **`course/eval/`** (or documented path)
# - [ ] At least one demo image or video in the README

# %%
from pathlib import Path

for sub in ("eval", "app"):
    p = Path(sub)
    print(sub, "->", "ok" if p.is_dir() else "missing")
