# %% [markdown]
# # Day 7 homework: Polish the repository
#
# Same focus as **`course/Day_07_Share_Results.ipynb`**, for **your** project (e.g. **`project/app/`** + Pydantic chunks).
#
# Goal: a README a reviewer can follow in a few minutes.

# %% [markdown]
# ## 1. Root `README.md`
#
# - **What** the agent does
# - **How to run** — `cd project/app`, `uv sync`, `OPENAI_API_KEY`, Streamlit / CLI
# - **Architecture** — ingest → chunk → index → Pydantic AI → UI
# - **Evaluation** — link **`project/eval/`** and headline **metrics**
# - **Demo** — video link or screenshots
# - **Credits** — libraries used
#
# Verify every command after editing.

# %% [markdown]
# ## 2. `project/eval/`
#
# Move stable flows out of **`Day_05_homework.ipynb`** if needed:
#
# - **`data-gen.ipynb`** — generated questions, batch runs
# - **`evaluations.ipynb`** — judge + Pandas summary
#
# Keep **`project/logs/`** gitignored; say so in the README.

# %% [markdown]
# ## 3. Demos
#
# Short recording or screenshots of the Streamlit app (and optionally CLI).

# %% [markdown]
# ## 4. Certificate (if applicable)
#
# Using **Pydantic docs** (not the course FAQ) satisfies a distinct-dataset requirement. You still need **pipeline, agent, evals, modular code, UI, README + demo** per official rules—confirm on the course site.

# %% [markdown]
# ## Deliverables
#
# | Task | Done |
# |------|------|
# | README with Evaluation + demo | ☐ |
# | `project/eval/` updated | ☐ |
# | Demo media in README | ☐ |
