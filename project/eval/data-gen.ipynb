# %% [markdown]
# # Evaluation data generation (project)
#
# Generate synthetic questions from **Pydantic doc chunks**, run **`doc_agent`** (or `pydantic_doc_agent` from `project/app/`), and write logs under **`project/logs/`** with `source='ai-generated'`.
#
# Start from **`project/Day_05_homework.ipynb`** (question generator + `tqdm` loop) and move the stable parts here.

# %% [markdown]
# ## Tip
#
# After migration, link this notebook from your root **`README.md`** and keep **`logs/`** gitignored.
