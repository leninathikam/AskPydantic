# %% [markdown]
# # Evaluations (project)
#
# Batch **LLM-as-judge** over `pydantic_doc_agent_*.json` logs with `source='ai-generated'`; build a **DataFrame** of checklist pass rates for the **README**.
#
# Reuse logic from **`project/Day_05_homework.ipynb`** (`evaluate_one`, Pandas aggregation).

# %% [markdown]
# ## Output for README
#
# Example line for **Evaluation**:
#
# > On N AI-generated queries: `answer_relevant` 100%, `answer_citations` 45%, … (see `evaluations.ipynb`).
